# %% [markdown]
# <a href="https://colab.research.google.com/github/karladcescuela-crypto/Ejercicio-2-Ciencia-de-datos-/blob/main/ejercicio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creacion de Hola Mundo

# %%
import pandas as pd
data = { 'Mensaje': ['Hola mundo']}
df =pd.DataFrame(data)
print(df)
# Out:
#       Mensaje
# 0  Hola mundo
